# %%
#Import required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style('darkgrid')
plt.rcParams['font.size']=15
plt.rcParams['figure.figsize']=(10,7)
plt.rcParams['figure.facecolor']='#FFE5B4'

# %%
data=pd.read_csv(r"C:\Users\hp\Documents\world-happiness-report-2021.csv")

# %%
data.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
data.tail()
# Out:
#     Country name  Regional indicator  Ladder score  \
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 144                           0.120         3.748         3.276
# 145                           0.074         3.611         3.322
# 146                           0.068         3.548         3.282
# 147                           0.058         3.259         3.030
# 148                           0.038         2.596         2.449
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 144                  7.926           0.787                   48.700
# 145                  9.782           0.784                   59.269
# ...

# %%
data.shape
# Out:
# (149, 20)

# %%
data.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
data_columns=['Country name','Regional indicator','Ladder score','Explained by: Log GDP per capita','Social support','Explained by: Healthy life expectancy','Freedom to make life choices','Explained by: Generosity','Perceptions of corruption']

# %%
data=data[data_columns].copy()

# %%
happy_df=data.rename({'Country Name':'country_name','Regional indicator':'regional_indicator','Ladder score':'happiness_score','Explained by: Log GDP per capita':'log_gdp_per_capita','Social support':'social_support','Explained by: Healthy life expectancy':'health_life_expectancy','Freedom to make life choices':'freedom_to_make_choices','Explained by: Generosity':'geneority','Perceptions of corruption':'perception_of_corruption'},axis=1)

# %%
happy_df
# Out:
#     Country name  regional_indicator  happiness_score  log_gdp_per_capita  \
# 0        Finland      Western Europe            7.842               1.446
# 1        Denmark      Western Europe            7.620               1.502
# 2    Switzerland      Western Europe            7.571               1.566
# 3        Iceland      Western Europe            7.554               1.482
# 4    Netherlands      Western Europe            7.464               1.501
# ..           ...                 ...              ...                 ...
# 144      Lesotho  Sub-Saharan Africa            3.512               0.451
# 145     Botswana  Sub-Saharan Africa            3.467               1.099
# 146       Rwanda  Sub-Saharan Africa            3.415               0.364
# 147     Zimbabwe  Sub-Saharan Africa            3.145               0.457
# 148  Afghanistan          South Asia            2.523               0.370
#
#      social_support  health_life_expectancy  freedom_to_make_choices  \
# ...

# %%
happy_df.head()
# Out:
#   Country name regional_indicator  happiness_score  log_gdp_per_capita  \
# 0      Finland     Western Europe            7.842               1.446
# 1      Denmark     Western Europe            7.620               1.502
# 2  Switzerland     Western Europe            7.571               1.566
# 3      Iceland     Western Europe            7.554               1.482
# 4  Netherlands     Western Europe            7.464               1.501
#
#    social_support  health_life_expectancy  freedom_to_make_choices  geneority  \
# 0           0.954                   0.741                    0.949      0.124
# 1           0.954                   0.763                    0.946      0.208
# 2           0.942                   0.816                    0.919      0.204
# 3           0.983                   0.772                    0.955      0.293
# 4           0.942                   0.753                    0.913      0.302
#
#    perception_of_corruption
# 0                     0.186
# ...

# %%
happy_df.tail()
# Out:
#     Country name  regional_indicator  happiness_score  log_gdp_per_capita  \
# 144      Lesotho  Sub-Saharan Africa            3.512               0.451
# 145     Botswana  Sub-Saharan Africa            3.467               1.099
# 146       Rwanda  Sub-Saharan Africa            3.415               0.364
# 147     Zimbabwe  Sub-Saharan Africa            3.145               0.457
# 148  Afghanistan          South Asia            2.523               0.370
#
#      social_support  health_life_expectancy  freedom_to_make_choices  \
# 144           0.787                   0.007                    0.715
# 145           0.784                   0.340                    0.824
# 146           0.552                   0.407                    0.897
# 147           0.750                   0.243                    0.677
# 148           0.463                   0.126                    0.382
#
#      geneority  perception_of_corruption
# 144      0.103                     0.915
# ...

# %%
happy_df.shape
# Out:
# (149, 9)

# %%
happy_df.isnull().sum()
# Out:
# Country name                0
# regional_indicator          0
# happiness_score             0
# log_gdp_per_capita          0
# social_support              0
# health_life_expectancy      0
# freedom_to_make_choices     0
# geneority                   0
# perception_of_corruption    0
# dtype: int64

# %%
#Plot between Happiness btw GDP
plt.rcParams['figure.figsize']=(15,7)
plt.title('Plot Between Happiness Score and GDP')
sns.scatterplot(x=happy_df.happiness_score,y=happy_df.log_gdp_per_capita,hue=happy_df.regional_indicator,s=200);

plt.legend(loc='upper left',fontsize='10')
plt.xlabel('Happiness Score')
plt.ylabel('GDP Per Capita')
# Out:
# Text(0, 0.5, 'GDP Per Capita')

# %%
gdp_region=happy_df.groupby('regional_indicator')['log_gdp_per_capita'].sum()
gdp_region
# Out:
# regional_indicator
# Central and Eastern Europe            20.631
# Commonwealth of Independent States    11.598
# East Asia                              7.824
# Latin America and Caribbean           19.108
# Middle East and North Africa          18.001
# North America and ANZ                  5.833
# South Asia                             5.007
# Southeast Asia                         8.762
# Sub-Saharan Africa                    18.112
# Western Europe                        30.721
# Name: log_gdp_per_capita, dtype: float64

# %%
gdp_region.plot.pie(autopct='%1.1f%%')
plt.title('GDP by Region')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
total_country=happy_df.groupby('regional_indicator')[['Country name']].count()
total_country
# Out:
#                                     Country name
# regional_indicator
# Central and Eastern Europe                    17
# Commonwealth of Independent States            12
# East Asia                                      6
# Latin America and Caribbean                   20
# Middle East and North Africa                  17
# North America and ANZ                          4
# South Asia                                     7
# Southeast Asia                                 9
# Sub-Saharan Africa                            36
# Western Europe                                21

# %%
#Correlation Map
cor=happy_df.corr(method="pearson")
f,ax=plt.subplots(figsize=(10,5))
sns.heatmap(cor,mask=np.zeros_like(cor,dtype=np.bool),
            cmap="Blues",square=True,ax=ax)
# Out:
# <ipython-input-32-a184e7f59311>:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(cor,mask=np.zeros_like(cor,dtype=np.bool),
# <AxesSubplot:>

# %%
happy_df.isnull().sum()
# Out:
# Country name                0
# regional_indicator          0
# happiness_score             0
# log_gdp_per_capita          0
# social_support              0
# health_life_expectancy      0
# freedom_to_make_choices     0
# geneority                   0
# perception_of_corruption    0
# dtype: int64

# %%
#Correption in region
corruption=happy_df.groupby('regional_indicator')[['perception_of_corruption']].mean()
corruption
# Out:
#                                     perception_of_corruption
# regional_indicator
# Central and Eastern Europe                          0.850529
# Commonwealth of Independent States                  0.725083
# East Asia                                           0.683333
# Latin America and Caribbean                         0.792600
# Middle East and North Africa                        0.762235
# North America and ANZ                               0.449250
# South Asia                                          0.797429
# Southeast Asia                                      0.709111
# Sub-Saharan Africa                                  0.765944
# Western Europe                                      0.523095

# %%
plt.rcParams['figure.figsize']=(12,8)
plt.title('Perception of Corruption in various countries')
plt.xlabel('Regions',fontsize=15)
plt.ylabel('Corruption Index',fontsize=15)
plt.xticks(rotation=30,ha='right')
plt.bar(corruption.index,corruption.perception_of_corruption)
# Out:
# <BarContainer object of 10 artists>

# %%
top_10=happy_df.head(10)

# %%
top_10
# Out:
#   Country name     regional_indicator  happiness_score  log_gdp_per_capita  \
# 0      Finland         Western Europe            7.842               1.446
# 1      Denmark         Western Europe            7.620               1.502
# 2  Switzerland         Western Europe            7.571               1.566
# 3      Iceland         Western Europe            7.554               1.482
# 4  Netherlands         Western Europe            7.464               1.501
# 5       Norway         Western Europe            7.392               1.543
# 6       Sweden         Western Europe            7.363               1.478
# 7   Luxembourg         Western Europe            7.324               1.751
# 8  New Zealand  North America and ANZ            7.277               1.400
# 9      Austria         Western Europe            7.268               1.492
#
#    social_support  health_life_expectancy  freedom_to_make_choices  geneority  \
# ...

# %%
bottom_10=happy_df.tail(10)
bottom_10
# Out:
#     Country name            regional_indicator  happiness_score  \
# 139      Burundi            Sub-Saharan Africa            3.775
# 140        Yemen  Middle East and North Africa            3.658
# 141     Tanzania            Sub-Saharan Africa            3.623
# 142        Haiti   Latin America and Caribbean            3.615
# 143       Malawi            Sub-Saharan Africa            3.600
# 144      Lesotho            Sub-Saharan Africa            3.512
# 145     Botswana            Sub-Saharan Africa            3.467
# 146       Rwanda            Sub-Saharan Africa            3.415
# 147     Zimbabwe            Sub-Saharan Africa            3.145
# 148  Afghanistan                    South Asia            2.523
#
#      log_gdp_per_capita  social_support  health_life_expectancy  \
# 139               0.000           0.490                   0.155
# 140               0.329           0.832                   0.272
# 141               0.433           0.702                   0.300
# ...

# %%
fig,axes=plt.subplots(1,2,figsize=(16,6))
plt.tight_layout(pad=2)
xlabels=top_10.Country name
axes[0].set_title('Top 10 Happiest Countries Life Expectancy')
axes[0].set_xticklabels(xlabels,rotations=45,ha='right')
sns.barplot(x=top_10.Countryname,y=top_10.health_life_expectancy,ax=axes[0])
axes[0].set_xlabel('Country Name')
axes[0].set_ylabel('Life Expectancy')

xlabels=bottom_10.Countryname
axes[1]=set_title('Bottom 10 Happiest Countries Life Expectancy')
axes[1].set_xticklabels(xlabels,rotations=45,ha='right')
sns.barplot(x=top_10.Countryname,y=top_10.health_life_expectancy,ax=axes[1])
axes[1].set_xlabel('Country Name')
axes[1].set_ylabel('Life Expectancy')
# Out:
#   File "<ipython-input-46-8b50f5e9557d>", line 3
#     xlabels=top_10.Country name
#                            ^
# SyntaxError: invalid syntax

# %%
country=happy_df.sort_values(by='perception_of_corruption').head(10)
plt.rcParams['figure.figsize']=(12,8)
plt.title('Perception of Corruption in various countries')
plt.xlabel('Regions',fontsize=15)
plt.ylabel('Corruption Index',fontsize=15)
plt.xticks(rotation=30,ha='right')
plt.bar(corruption.index,corruption.perception_of_corruption)
# Out:
# <BarContainer object of 10 artists>

# %%
#Corruption vs Happiness
plt.rcParams['figure.figsize']=(15,7)
plt.title('Plot Between Happiness Score and GDP')
sns.scatterplot(x=happy_df.happiness_score,y=happy_df.perception_of_corruption,hue=happy_df.regional_indicator,s=200);

plt.legend(loc='lower left',fontsize='14')
plt.xlabel('Corruption')
plt.ylabel('Happiness Score')
# Out:
# Text(0, 0.5, 'Happiness Score')

# %%
happy_df.describe()
# Out:
#        happiness_score  log_gdp_per_capita  social_support  \
# count       149.000000          149.000000      149.000000
# mean          5.532839            0.977161        0.814745
# std           1.073924            0.404740        0.114889
# min           2.523000            0.000000        0.463000
# 25%           4.852000            0.666000        0.750000
# 50%           5.534000            1.025000        0.832000
# 75%           6.255000            1.323000        0.905000
# max           7.842000            1.751000        0.983000
#
#        health_life_expectancy  freedom_to_make_choices   geneority  \
# count              149.000000               149.000000  149.000000
# mean                 0.520161                 0.791597    0.178047
# std                  0.213019                 0.113332    0.098270
# min                  0.000000                 0.382000    0.000000
# 25%                  0.357000                 0.718000    0.105000
# ...

# %%
happy_df.boxplot('happiness_score')
# Out:
# <AxesSubplot:>
